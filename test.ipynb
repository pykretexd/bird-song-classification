# %%
import pandas as pd
import librosa
import librosa.display
import numpy as np
import os
from scipy.io.wavfile import read, write
import matplotlib.pyplot as plt

# %%
y, sr = librosa.load('C:/Users/elev/Documents/GitHub/CNN-audio-classification/audio/ogg/Acrocephalus-arundinaceus-131536.ogg')
mel_s = librosa.feature.melspectrogram(y, sr)
mel_spectrogram = librosa.power_to_db(mel_s, ref=np.max)
librosa.display.specshow(mel_spectrogram)
# Out:
# C:\Users\elev\AppData\Local\Temp\ipykernel_35776\1810783562.py:2: FutureWarning: Pass y=[ 3.3199267e-08 -6.2763931e-08  1.3345132e-07 ...  4.7206553e-03
#   9.3060927e-03  6.6819177e-03], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_s = librosa.feature.melspectrogram(y, sr)

# %%
y, sr = librosa.load('C:/Users/elev/Documents/GitHub/CNN-audio-classification/audio/wav/Acrocephalus-arundinaceus-131536.wav')
mel_s = librosa.feature.melspectrogram(y, sr)
mel_spectrogram = librosa.power_to_db(mel_s, ref=np.max)
librosa.display.specshow(mel_spectrogram)
# Out:
# C:\Users\elev\AppData\Local\Temp\ipykernel_35776\1809252303.py:2: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_s = librosa.feature.melspectrogram(y, sr)
